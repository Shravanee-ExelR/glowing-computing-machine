# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravanee-ExelR/glowing-computing-machine/blob/main/Syntecxhub_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e3b22e09-c7ad-461c-b414-64a88e684382" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3b22e09-c7ad-461c-b414-64a88e684382">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Project.csv")
#view data
df.head()
# Out:
#    Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 0           1   15  Female         College  Hyderabad      Copilot
# 1           2   21  Female      University    Chennai      Copilot
# 2           3   22    Male      University  Bangalore       Gemini
# 3           4   22    Male         College  Hyderabad      ChatGPT
# 4           5   22    Male         College  Hyderabad       Gemini
#
#    Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# 0                1.1  Learning   Slight Decline             Medium
# 1                1.7    Coding   Slight Decline               High
# 2                1.5  Learning         Improved                Low
# 3                3.8  Research         Improved                Low
# 4                5.2    Coding   Slight Decline                Low

# %%
df.tail()
# Out:
#      Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 195         196   20  Female         College  Bangalore      Copilot
# 196         197   19  Female          School       Pune       Gemini
# 197         198   24    Male      University  Ahmedabad       Gemini
# 198         199   16    Male         College     Jaipur       Gemini
# 199         200   16  Female      University     Mumbai      Copilot
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# 195                4.2  Learning         Improved                Low
# 196                1.7   Writing         Improved                Low
# 197                5.8    Coding         Improved             Medium
# 198                2.9  Learning         Improved             Medium
# 199                1.3    Coding   Slight Decline               High

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          200 non-null    int64
#  1   Age                 200 non-null    int64
#  2   Gender              200 non-null    object
#  3   Education_Level     200 non-null    object
#  4   City                200 non-null    object
#  5   AI_Tool_Used        200 non-null    object
#  6   Daily_Usage_Hours   200 non-null    float64
#  7   Purpose             200 non-null    object
#  8   Impact_on_Grades    200 non-null    object
#  9   Satisfaction_Level  200 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 15.8+ KB

# %%
df.dtypes
# Out:
# Student_ID              int64
# Age                     int64
# Gender                 object
# Education_Level        object
# City                   object
# AI_Tool_Used           object
# Daily_Usage_Hours     float64
# Purpose                object
# Impact_on_Grades       object
# Satisfaction_Level     object
# dtype: object

# %%
df.shape
# Out:
# (200, 10)

# %%
df.describe()
#mean,median,min,max,count
print("Mean:\n",df.mean(numeric_only=True))
print("Median:\n",df.median(numeric_only=True))
print("Max:\n",df.max(numeric_only=True))
print("Min:\n",df.min(numeric_only=True))
print("Count:\n",df.count(numeric_only=True))
# Out:
# Mean:
#  Student_ID           100.500
# Age                   19.620
# Daily_Usage_Hours      2.857
# dtype: float64
# Median:
#  Student_ID           100.5
# Age                   20.0
# Daily_Usage_Hours      2.8
# dtype: float64
# Max:
#  Student_ID           200.0
# Age                   24.0
# Daily_Usage_Hours      5.9
# dtype: float64
# Min:
#  Student_ID            1.0
# Age                  15.0
# Daily_Usage_Hours     0.5
# dtype: float64
# Count:
#  Student_ID           200
# Age                  200
# Daily_Usage_Hours    200
# dtype: int64

# %%
#filtered rows that contains columns

filtered=df[df["Daily_Usage_Hours"]>3]
filtered.head()
# Out:
#     Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 3            4   22    Male         College  Hyderabad      ChatGPT
# 4            5   22    Male         College  Hyderabad       Gemini
# 6            7   15  Female          School       Pune      Copilot
# 9           10   19  Female          School    Chennai      ChatGPT
# 10          11   22    Male          School     Jaipur      ChatGPT
#
#     Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# 3                 3.8  Research         Improved                Low
# 4                 5.2    Coding   Slight Decline                Low
# 6                 4.5    Coding   Slight Decline               High
# 9                 5.5  Research         Improved                Low
# 10                4.4    Coding        No Change             Medium

# %%
#select columns
df[["Daily_Usage_Hours","Impact_on_Grades"]]
df["Purpose"]
# Out:
# 0      Learning
# 1        Coding
# 2      Learning
# 3      Research
# 4        Coding
#          ...
# 195    Learning
# 196     Writing
# 197      Coding
# 198    Learning
# 199      Coding
# Name: Purpose, Length: 200, dtype: object

# %%
#slice data
df.iloc[0:10]  #first 10 rows
df.iloc[:,0:5]  #first 5 columns
# Out:
#      Student_ID  Age  Gender Education_Level       City
# 0             1   15  Female         College  Hyderabad
# 1             2   21  Female      University    Chennai
# 2             3   22    Male      University  Bangalore
# 3             4   22    Male         College  Hyderabad
# 4             5   22    Male         College  Hyderabad
# ..          ...  ...     ...             ...        ...
# 195         196   20  Female         College  Bangalore
# 196         197   19  Female          School       Pune
# 197         198   24    Male      University  Ahmedabad
# 198         199   16    Male         College     Jaipur
# 199         200   16  Female      University     Mumbai
#
# [200 rows x 5 columns]

# %%
#save to csv
filtered.to_csv("filtered_project.csv",index=False)

# %%
#download
files.download("filtered_project.csv")

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(10,5))
plt.show()
